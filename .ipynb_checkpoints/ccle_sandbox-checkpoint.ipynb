# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
import cloveFunctions as clv
import matplotlib
# matplotlib.use('Qt4Agg')
import matplotlib.pyplot as plt
# matplotlib.rcParams['figure.figsize'] = (20.0, 10.0)
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df = pd.DataFrame({ 'gene':["1 // foo // blabla",
                                   "2 // bar // lalala",
                                   "3 // qux // trilil",
                                   "4 // woz // hohoho",
                                   "nopeynope"], 
                   'cnv':['a','b','c','d','e'],
                   'cell1':[5,9,1,7,9], 
                   'cell2':[12,90,13,87,9],
                   'location':['1', '13.4', '1.1-2', '1.2-p22', '43-q44'],
                  'np_t_w': ['1','13.4','1.1','2','3']})
df['exp'] = ['e','f','g','h','i']
df
# Out:
#    cell1  cell2 cnv                gene location np_t_w exp
# 0      5     12   a  1 // foo // blabla        1      1   e
# 1      9     90   b  2 // bar // lalala     13.4   13.4   f
# 2      1     13   c  3 // qux // trilil    1.1-2    1.1   g
# 3      7     87   d  4 // woz // hohoho  1.2-p22      2   h
# 4      9      9   e           nopeynope   43-q44      3   i

# %%
cnv = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], index=['a', 'b','x'])
exp = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], index=['e', 'h','x'])

# %%
df[(df['cnv'].isin(cnv.index)) & (df['exp'].isin(exp.index))]
# Out:
#    cell1  cell2 cnv                gene location np_t_w exp
# 0      5     12   a  1 // foo // blabla        1      1   e

# %%
results = []
for pddf in [df, cnv, exp]:
    results.append(pddf)

for p in results:
    print(p)
# Out:
#    cell1  cell2 cnv                gene location np_t_w exp
# 0      5     12   a  1 // foo // blabla        1      1   e
# 1      9     90   b  2 // bar // lalala     13.4   13.4   f
# 2      1     13   c  3 // qux // trilil    1.1-2    1.1   g
# 3      7     87   d  4 // woz // hohoho  1.2-p22      2   h
# 4      9      9   e           nopeynope   43-q44      3   i
#    0  1  2
# a  1  2  3
# b  4  5  6
# x  7  8  9
#    0  1  2
# e  1  2  3
# h  4  5  6
# x  7  8  9

# %%
df['location'].str.extract('(-)', expand=True)
# Out:
#      0
# 0  NaN
# 1  NaN
# 2    -
# 3    -
# 4    -

# %%
df = pd.DataFrame([['a','b',1,'1p1'],
                  ['a','c',1.9,'1p1'],
                  ['a','d',45,'1p1'],
                  ['a','e',3.9,'1p1'],
                  ['b','c', 2.1,'1p2'],
                  ['b','d',-2,'1p2'],
                  ['b','e',4.1,'1p2'],
                  ['c','b',2,'1p3'],
                  ['c','c',2,'1p3'],
                  ['c','d',2,'1p3'],
                  ['c','e',2,'1p3'],
                  ['d','b',2,'1p4'],
                  ['d','c',2,'1p4'],
                  ['d','d',2,'1p4'],
                  ['d','e',2,'1p4']],
                 columns = ['cnv','exp','np_t_w', 'chromosome'])
df
# Out:
#    cnv exp  np_t_w chromosome
# 0    a   b     1.0        1p1
# 1    a   c     1.9        1p1
# 2    a   d    45.0        1p1
# 3    a   e     3.9        1p1
# 4    b   c     2.1        1p2
# 5    b   d    -2.0        1p2
# 6    b   e     4.1        1p2
# 7    c   b     2.0        1p3
# 8    c   c     2.0        1p3
# 9    c   d     2.0        1p3
# 10   c   e     2.0        1p3
# 11   d   b     2.0        1p4
# 12   d   c     2.0        1p4
# 13   d   d     2.0        1p4
# 14   d   e     2.0        1p4

# %%
rolling_similarity(df, how='cosine', group='cnv',data='np_t_w')
# Out:
#   chromosome cnv_g0 exp  clove_g0 cnv_g1  clove_g1
# 0        1p1      a   c       1.9      b       2.1
# 1        1p1      a   d      45.0      b      -2.0
# 2        1p1      a   e       3.9      b       4.1
#   chromosome cnv_g0 exp  clove_g0 cnv_g1  clove_g1
# 0        1p1      a   b       1.0      c       2.0
# 1        1p1      a   c       1.9      c       2.0
# 2        1p1      a   d      45.0      c       2.0
# 3        1p1      a   e       3.9      c       2.0
#   chromosome cnv_g0 exp  clove_g0 cnv_g1  clove_g1
# 0        1p1      a   b       1.0      d       2.0
# 1        1p1      a   c       1.9      d       2.0
# 2        1p1      a   d      45.0      d       2.0
# 3        1p1      a   e       3.9      d       2.0
#   chromosome cnv_g0 exp  clove_g0 cnv_g1  clove_g1
# 0        1p2      b   c       2.1      c       2.0
# 1        1p2      b   d      -2.0      c       2.0
# 2        1p2      b   e       4.1      c       2.0
#   chromosome cnv_g0 exp  clove_g0 cnv_g1  clove_g1
# 0        1p2      b   c       2.1      d       2.0
# 1        1p2      b   d      -2.0      d       2.0
# 2        1p2      b   e       4.1      d       2.0
#   chromosome cnv_g0 exp  clove_g0 cnv_g1  clove_g1
# 0        1p3      c   b       2.0      d       2.0
# 1        1p3      c   c       2.0      d       2.0
# 2        1p3      c   d       2.0      d       2.0
# 3        1p3      c   e       2.0      d       2.0
#   cnv exp    cosine
# 0   a   b -0.308410
# 1   a   c  0.572759
# 2   a   d  0.572759
# 3   b   c  0.482854
# 4   b   d  0.482854
# 5   c   d  1.000000

# %%
from scipy.stats import pearsonr
from scipy.spatial import distance
from sklearn.metrics.pairwise import cosine_similarity

def rolling_similarity(df, group='cnv', partners='exp', data='np_t_w', how='pearson', locus='chromosome'):
    """
    computes similarity between array of data for one gene partners and each successive chromosomal neighbor
    
    :param df: pd df, clove results, sorted in ascending order of chromosome locus
    :param group: str, df column label on which to form gene neigbors, default 'cnv'
    :param members: str, df column label on which to pair partners with gene neighbors, default 'exp'
    :param data: str, df column label of source data to populate arrays, default 'np_t_w' (clove t-stats)
    :param how: str, choice of: {pearson, euclidian, cosine}
    :param align: bool, False compares two arrays which don't necessarily have same gene index
    
    returns pd df of pairs, scores, and chosen similary metric, ordered by locus
    """
    
    unique_genes = df[group].unique()
    df = df[[locus, group, partners, data]].sort_values(by=locus)
    results = []
    for idx, g0 in enumerate(unique_genes):
        if idx < len(unique_genes) - 1:
            for idxk, gk in enumerate(unique_genes[idx+1:]):
                g1 = gk  # unique_genes[idx+1]
                merged = pd.merge(df[df[group] == g0], df[df[group] == g1][[partners,group,data]], how='inner', on=partners)
                merged.columns = [locus,'cnv_g0','exp','clove_g0','cnv_g1','clove_g1']
                print(merged)

                if how == 'pearson':
                    # produces NaN
                    cols = [group, partners, how ,'pval']
                    pear, pval = pearsonr(merged['clove_g0'], merged['clove_g1'])
                    results.append([g0,g1,pear,pval])
                elif how == 'euclidian':
                    cols = [group, partners, how]
                    d = distance.euclidean(merged['clove_g0'], merged['clove_g1'])
                    # error: (offx>=0 && offx<len(x)) failed for 2nd keyword offx: dnrm2:offx=0
                    results.append([g0, g1, d])
                elif how == 'cosine':
                    cols = [group, partners, how]
                    # error: (offx>=0 && offx<len(x)) failed for 2nd keyword offx: dnrm2:offx=0
                    d = cosine_similarity(merged['clove_g0'], merged['clove_g1'])[0][0]  
                    results.append([g0, g1, d])

#     return map_locus(pd.DataFrame(results, columns=cols))
    return pd.DataFrame(results, columns=cols)

# %%
df
# Out:
#    cell1  cell2 cnv                gene location np_t_w
# 0      5     12   a  1 // foo // blabla        1      1
# 1      9     90   b  2 // bar // lalala     13.4   13.4
# 2      1     13   c  3 // qux // trilil    1.1-2    1.1
# 3      7     87   d  4 // woz // hohoho  1.2-p22      2
# 4      9      9   e           nopeynope   43-q44      3

# %%
pearsonr?

# %% [markdown]
# develop explicit way to define certain combinations of genes on which to compute CLOvEs

# %%
import pandas as pd
import numpy as np
from scipy import stats
from cloveFunctions import *
import itertools

# %%
edf = pd.read_csv('data/breast_mrna.tab.gz', compression='gzip', sep='\t', index_col=0)
cdf = pd.read_csv('data/breast_CCLE_DEL_calls.csv.gz', compression='gzip', index_col=0)

# %%
e_samp = edf.index[1:3].values
c_samp = cdf.index[3:5].values

# %%
c_samp
# Out:
# array(['A2LD1', 'A2M'], dtype=object)

# %%
edf_f, cdf_f = mainFitler(edf, cdf, var=2, n=6, amp_fh=False, dele_fh=False, mut_fh=False, save=False)
df = explicitPairContextStat(edf_f, cdf_f, cnv_lis=c_samp)
# Out:
# attempting 3376 comparisons with current parameters

# %%
map_locus(df)
# Out:
#     cnv           exp  pos_n  neg_n     pos_mu     neg_mu   pos_var   neg_var  \
# 0   A2M         AP1S2      6     53   7.319589   7.507049  1.387391  2.894021
# 22  A2M         MIEN1      6     53  11.207608  11.165550  2.228997  2.436755
# 23  A2M          MLPH      6     53  10.511819  10.505350  5.335603  4.699409
# 24  A2M          MREG      6     53   7.900807   7.478374  0.970711  2.610663
# 25  A2M          NAT1      6     53   8.542979   8.340457  3.623388  2.661422
# 26  A2M          OPN3      6     53   7.683450   8.180795  1.802795  2.257083
# 27  A2M         PDCD4      6     53   8.866148   8.602590  3.990745  2.304567
# 28  A2M       PLEKHF2      6     53   9.611975   9.099866  0.481288  2.389591
# 29  A2M          PLK2      6     53  11.220978  10.387761  0.711472  2.207939
# 30  A2M     RAB11FIP1      6     53   8.788833   8.510063  0.573247  2.737802
# 31  A2M       RHOBTB3      6     53  10.228904   9.561398  2.652496  2.988565
# 32  A2M         RHPN2      6     53   9.985350   8.901847  2.225273  2.340111
# 33  A2M          RND3      6     53  11.167418  10.753019  0.959906  2.783227
# 34  A2M           SFN      6     53  11.600985  10.404055  4.526207  5.555937
# 35  A2M        SH3YL1      6     53  10.493780  10.410062  0.593139  2.342898
# 36  A2M       SLC7A11      6     53   7.189081   7.894026  0.786334  2.271289
# 37  A2M         SNHG5      6     53  11.823638  11.003988  0.188094  2.192168
# 38  A2M        TFAP2A      6     53   8.753469   8.842661  2.342096  2.721972
# 21  A2M          MAFF      6     53   8.992966   9.317215  2.160863  3.061501
# 39  A2M         TRPS1      6     53   9.751949   8.893529  3.410280  4.139763
# 20  A2M  LOC100128822      6     53   9.037838   8.406767  0.668205  2.654896
# 18  A2M         IL6ST      6     53   9.011850   8.595864  1.600049  2.008310
# 1   A2M           CD9      6     53  11.124205  11.770434  2.169280  1.951835
# 2   A2M         CEBPD      6     53   8.758002   8.828830  2.069576  2.236029
# 3   A2M         COTL1      6     53   7.759879   9.041548  2.323716  3.839703
# 4   A2M       CREB3L4      6     53   9.549590   8.792282  2.026261  4.506132
# 5   A2M         CXXC5      6     53   9.995787  10.054935  1.654952  2.144596
# 6   A2M        DNAJB4      6     53   7.115043   7.727819  1.058577  2.512182
# 7   A2M        DYNLT3      6     53  11.018540  10.428015  0.749428  2.352246
# 8   A2M          ELL3      6     53   8.623390   7.836259  2.271842  2.187100
# 9   A2M          EXT1      6     53   9.790400   9.814188  2.479797  2.433721
# 10  A2M        FAM46A      6     53   7.776968   8.632040  1.593730  2.141067
# 11  A2M        FAM69A      6     53   7.526840   7.315498  1.675198  2.601364
# 12  A2M         FRMD6      6     53   9.815298   9.603294  2.445011  2.521435
# 13  A2M          HES1      6     53   9.347254   8.683709  0.749990  2.610954
# 14  A2M     HIST1H2BD      6     53   9.836134   9.143989  1.433637  2.412976
# 15  A2M     HIST2H2BE      6     53   8.304559   8.373608  1.962116  2.649944
# 16  A2M           ID1      6     53  12.669085  11.676975  0.794355  3.410146
# 17  A2M         IKBIP      6     53   6.473131   6.504702  0.632382  2.415719
# 19  A2M        KDELR3      6     53   8.161526   9.132145  1.697710  1.914878
# 40  A2M       TSPAN13      6     53  12.246213  11.942926  2.374796  2.814186
#
#     cohens_d      np_t_w    np_p_w  gene_var_exp chromosome
# 0  -0.111297   -0.258386  0.797039      2.791326   12p13.31
# 22  0.026598   0.0617499  0.950978      2.457440   12p13.31
# 23  0.002913  0.00676354  0.994627      4.846250   12p13.31
# 24  0.265600    0.616617  0.539942      2.502608   12p13.31
# 25  0.119836    0.278212  0.781857      2.810634   12p13.31
# 26 -0.328765   -0.763261  0.448455      2.271989   12p13.31
# 27  0.164630    0.382205  0.703731      2.525188   12p13.31
# 28  0.339707    0.788664  0.433576      2.257751   12p13.31
# 29  0.571194     1.32608  0.190101      2.155715   12p13.31
# 30  0.172686    0.400909  0.689986      2.568308   12p13.31
# 31  0.381709    0.886177  0.379246      3.046731   12p13.31
# 32  0.697926     1.62031  0.110686      2.477674   12p13.31
# 33  0.252713    0.586698  0.559723      2.658553   12p13.31
# 34  0.503887     1.16982   0.24694      5.678338   12p13.31
# 35  0.055925    0.129835  0.897154      2.202934   12p13.31
# 36 -0.475850    -1.10473  0.273917      2.203013   12p13.31
# 37  0.571336     1.32642  0.189992      2.085078   12p13.31
# 38 -0.053518   -0.124248  0.901556      2.730344   12p13.31
# 21 -0.184935   -0.429344  0.669291      3.030886   12p13.31
# 39  0.418457    0.971489  0.335409      4.204152   12p13.31
# 20  0.396053    0.919477  0.361721      2.532159   12p13.31
# 18  0.291549     0.67686  0.501232      2.016782   12p13.31
# 1  -0.452095    -1.04958  0.298339      2.046789   12p13.31
# 2  -0.046733   -0.108496  0.913983      2.257828   12p13.31
# 3  -0.656201    -1.52344  0.133179      3.901729   12p13.31
# 4   0.360901    0.837869  0.405604      4.380581   12p13.31
# 5  -0.040167  -0.0932528   0.92603      2.131244   12p13.31
# 6  -0.391703   -0.909377   0.36698      2.440017   12p13.31
# 7   0.392285     0.91073  0.366273      2.259399   12p13.31
# 8   0.522120     1.21215  0.230454      2.291151   12p13.31
# 9  -0.014973   -0.034762  0.972391      2.480501   12p13.31
# 10 -0.581994    -1.35116  0.181984      2.189305   12p13.31
# 11  0.131191    0.304572  0.761801      2.554555   12p13.31
# 12  0.131433    0.305134  0.761376      2.561179   12p13.31
# 13  0.419104    0.972991  0.334669      2.504373   12p13.31
# 14  0.447286     1.03842   0.30346      2.397787   12p13.31
# 15 -0.042253  -0.0980937  0.922202      2.624921   12p13.31
# 16  0.549947     1.27676  0.206865      3.289810   12p13.31
# 17 -0.020760   -0.048196  0.961729      2.272979   12p13.31
# 19 -0.693440    -1.60989  0.112947      2.012975   12p13.31
# 40  0.179128    0.415864  0.679071      2.825800   12p13.31

# %%
df['exp'].value_counts()
# Out:
# SH3YL1          2
# RHPN2           2
# HIST1H2BD       2
# OPN3            2
# HIST2H2BE       2
# PLEKHF2         2
# LOC100128822    2
# MLPH            2
# PLK2            2
# SNHG5           2
# NAT1            2
# IL6ST           2
# TSPAN13         2
# CXXC5           2
# RND3            2
# DYNLT3          2
# TRPS1           2
# DNAJB4          2
# RAB11FIP1       2
# COTL1           2
# FAM69A          2
# MREG            2
# IKBIP           2
# AP1S2           2
# SFN             2
# KDELR3          2
# RHOBTB3         2
# MIEN1           2
# CD9             2
# FRMD6           2
# HES1            2
# TFAP2A          2
# CEBPD           2
# CREB3L4         2
# SLC7A11         2
# FAM46A          2
# ID1             2
# EXT1            2
# MAFF            2
# PDCD4           2
# ELL3            2
# Name: exp, dtype: int64

# %%
cbar = fig.colorbar

# %% [markdown]
# ### Subset large intestine data to get to 5 viz bait contexts

# %% [markdown]
# large intestine (source of viz dataset) doesn't have enough n-samples with context (probably why these were induced knockouts)"

# %%
csv = pd.read_csv('data/large_intestine_CCLE_DEL_calls.csv.gz', compression='gzip', index_col=0)
viz_bait = ['PTTG1', 'BLM','MUS81', 'PTEN', 'KRAS']
csv.loc[viz_bait].sum(axis=1)
# csv[csv['Name'].isin(viz_bait)]
# Out:
# Name
# PTTG1    0
# BLM      0
# MUS81    2
# PTEN     1
# KRAS     0
# dtype: int64

# %% [markdown]
# use all ccle cell lines

# %%
csv = pd.read_pickle('data/CCLE_DEL_calls.pickle')
viz_bait = ['PTTG1', 'BLM','MUS81', 'PTEN', 'KRAS']
csv = csv.loc[viz_bait].sum(axis=1)
csv.to_pickle('data/CCLE_DEL_calls_viz.pickle')
# Out:
# Name
# PTTG1     18
# BLM       19
# MUS81      9
# PTEN     102
# KRAS      31
# dtype: int64

# %%
explicitPairContextStat?

# %%
viz = pd.read_csv('data/viz_HCT116_GARP-score.txt.tar.gz',sep='\t', compression='gzip', index_col=0)

# %%
del viz['Gene ID']
del viz['Description']
del viz['Unnamed: 10']
viz.set_index('Gene Name', drop=True, inplace=True)
viz
# Out:
#            HCT116_BLM  HCT116_MUS81  HCT116_PTEN  HCT116_PWT  HCT116_PTTG1  \
# Gene Name
# WDR11       -0.156363     -0.306122    -0.357102   -0.084159     -0.413263
# OR10A2      -0.055357     -0.109505    -0.077226   -0.070077     -0.127857
# MRPS12      -0.111989     -0.059505    -0.184910   -0.066028     -0.217499
# MPV17L      -0.036167     -0.148610    -0.225790   -0.068753     -0.239617
# TFPI2       -0.180304     -0.315834    -0.387426   -0.190001     -0.292052
# NUDT15      -0.019991     -0.096132    -0.135179   -0.073432     -0.187830
# TRMT1       -0.319461     -0.101908    -0.093429   -0.118008     -0.220807
# PNOC         0.019299     -0.086702    -0.001842   -0.071489     -0.029707
# EVI2B       -0.018433     -0.155776    -0.078900   -0.057902     -0.229445
# HK3         -0.113540     -0.028631    -0.037378   -0.048561     -0.061255
# AGFG1       -0.062630     -0.065336    -0.066164   -0.078525     -0.072538
# NWD1        -0.009786     -0.103427    -0.063180   -0.106628     -0.205123
# CDC25B      -0.092404     -0.103487    -0.166873   -0.048538     -0.184975
# IPO5        -0.208528     -0.340174    -0.262764   -0.246461     -0.319482
# MBTPS2      -0.119571     -0.118791    -0.072304   -0.145386     -0.286578
# ADAMTS6     -0.059571     -0.276760    -0.083523   -0.137765     -0.201081
# C18orf26    -0.055102     -0.074424    -0.111170   -0.082542     -0.142821
# PRDM16      -0.306788     -0.352801    -0.348216   -0.229299     -0.407372
# PCDHA2      -0.104594     -0.034646    -0.062603   -0.053832     -0.177557
# ATM         -0.262931     -0.140271    -0.201735   -0.143126     -0.437028
# RPL10L      -0.085137     -0.066268    -0.109195   -0.124690     -0.151267
# CHCHD3      -0.060896     -0.041845     0.014596   -0.034407     -0.101332
# MTTP        -0.079989     -0.082217    -0.055620   -0.154760     -0.185084
# ZNF322B     -0.036524     -0.062618    -0.035569   -0.057764     -0.096622
# C2orf48     -0.086632     -0.188499    -0.323291   -0.066501     -0.459105
# GYLTL1B     -0.146731     -0.212518    -0.154975   -0.188583     -0.289300
# LILRA1      -0.011010     -0.021937    -0.023797   -0.021817     -0.046927
# SLC7A4      -0.053646     -0.145044    -0.093997   -0.070052     -0.243181
# RTDR1       -0.225225     -0.220668    -0.204138   -0.173961     -0.387981
# SIX4         0.044502     -0.060217    -0.003129   -0.016879     -0.195247
# ...               ...           ...          ...         ...           ...
# NR1D2       -0.024320     -0.064596     0.016439   -0.064482     -0.147274
# CRLS1       -0.005607     -0.033849    -0.042858   -0.031634     -0.076191
# LCN2        -0.040824     -0.065197    -0.124370   -0.075300     -0.218833
# SNRNP25     -0.183204     -0.223681    -0.238966   -0.383539     -0.383436
# DHRSX        0.004372     -0.058846    -0.054757   -0.032418     -0.045725
# ATP6V1B1    -0.003800     -0.080463    -0.115551   -0.060708     -0.208611
# ZFYVE19     -0.111935     -0.120309    -0.214380   -0.091961     -0.228895
# CXCL11      -0.037574     -0.029247    -0.064663   -0.051159     -0.069725
# ALDH2       -0.148877     -0.306251    -0.183207   -0.185887     -0.361499
# GPR37       -0.219126     -0.161423    -0.119352   -0.156892     -0.421172
# KIAA1826     0.013196     -0.018099    -0.071359   -0.057302     -0.143625
# SENP7       -0.148134     -0.198555    -0.114743   -0.062903     -0.158433
# CEACAM7     -0.061692     -0.109746    -0.132976   -0.126997     -0.201453
# -           -0.093911     -0.134310    -0.172989   -0.131672     -0.190048
# LGALS2      -0.057834     -0.053017    -0.070173   -0.047023     -0.052493
# FANCL       -0.070033     -0.178037    -0.141973   -0.110448     -0.311022
# GIMAP5      -0.145953     -0.204169    -0.077858   -0.171802     -0.427008
# TCP11L1     -0.191696     -0.279673    -0.208762   -0.248061     -0.453932
# CABYR       -0.008479     -0.035987    -0.084196   -0.030750     -0.215195
# ERI1        -0.027925     -0.141003    -0.165115   -0.072320     -0.346767
# C4orf43     -0.133523     -0.132043    -0.117181   -0.073440     -0.273787
# ANKS6       -0.064885     -0.184478    -0.125770   -0.077913     -0.140811
# RASSF3       0.049343      0.011899     0.058159   -0.017560     -0.030988
# LTB4R2       0.026701      0.000001    -0.089636    0.002875     -0.008563
# FOXN3       -0.024253     -0.070035    -0.065657   -0.060663     -0.090545
# PAG1        -0.106627     -0.193799    -0.108104   -0.104104     -0.259046
# GTF2H3       0.026124     -0.122165    -0.047274   -0.062752     -0.094148
# CAPN3       -0.107531     -0.212369    -0.288928   -0.150891     -0.306028
# KANK4       -0.069439     -0.145392    -0.030039   -0.107276     -0.206020
# NaN               NaN           NaN          NaN         NaN           NaN
#
#            HCT116_WT
# Gene Name
# WDR11      -0.121228
# OR10A2     -0.059772
# MRPS12     -0.039225
# MPV17L     -0.051944
# TFPI2      -0.091514
# NUDT15     -0.051562
# TRMT1      -0.064457
# PNOC       -0.009812
# EVI2B      -0.065921
# HK3        -0.041679
# AGFG1      -0.062813
# NWD1       -0.038407
# CDC25B     -0.039276
# IPO5       -0.203630
# MBTPS2     -0.085120
# ADAMTS6    -0.103910
# C18orf26   -0.040962
# PRDM16     -0.168383
# PCDHA2     -0.050346
# ATM        -0.121903
# RPL10L     -0.088525
# CHCHD3     -0.093883
# MTTP       -0.071512
# ZNF322B    -0.035318
# C2orf48    -0.096412
# GYLTL1B    -0.175253
# LILRA1     -0.026233
# SLC7A4     -0.077161
# RTDR1      -0.123711
# SIX4       -0.064975
# ...              ...
# NR1D2      -0.044648
# CRLS1      -0.031422
# LCN2       -0.089820
# SNRNP25    -0.139446
# DHRSX      -0.005668
# ATP6V1B1   -0.058978
# ZFYVE19    -0.088010
# CXCL11     -0.034676
# ALDH2      -0.113884
# GPR37      -0.117653
# KIAA1826   -0.019804
# SENP7      -0.063731
# CEACAM7    -0.081551
# -          -0.085139
# LGALS2     -0.059808
# FANCL      -0.075950
# GIMAP5     -0.214952
# TCP11L1    -0.191937
# CABYR      -0.047818
# ERI1       -0.063954
# C4orf43    -0.126909
# ANKS6      -0.048461
# RASSF3      0.002505
# LTB4R2      0.051410
# FOXN3      -0.074165
# PAG1       -0.104324
# GTF2H3     -0.044257
# CAPN3      -0.108942
# KANK4      -0.072337
# NaN              NaN
#
# [16029 rows x 6 columns]

# %% [markdown]
# ## Compute Some Sample Breast CLOvE

# %%
from cloveFunctions import *

def compute_breast_cloves(save=False):
    calls = pd.read_pickle('data_large/CCLE_DEL_calls.pickle')
    cellinfo = pd.read_pickle('data_large/ccle_cell_info_df.pickle')
    kidcnv = pd.read_pickle('data/kidney_cnv_df.pickle')
    kidexp = pd.read_pickle('data/kidney_mrna_df.pickle')

    # this filtering step requires subsetting cdel to tissue of interest (breast)
    cells = list(set(cdel.columns).intersection(exp_breast.columns)) # eliminating all contexts less than 2
    cdel_breast = cdel[cells]
    df=randomPairContextStat(100000, exp_breast, cdel_breast, nan_style='propagate')
    
    if save:
        df.to_csv('data/breast_ttest_real_samp.tab.gz', sep='\t', compression='gzip')
    return df

def load_breast_cloves():
    return  pd.read_csv('data/breast_ttest_real_samp.tab.gz', sep='\t', compression='gzip', index_col=0)

# %% [markdown]
# ## Compute Some Kidney CLOvE

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
import cloveFunctions as clv
import matplotlib
# matplotlib.use('Qt4Agg')
import matplotlib.pyplot as plt
# matplotlib.rcParams['figure.figsize'] = (20.0, 10.0)
import warnings
warnings.filterwarnings('ignore')

# %%
celldf[celldf['Site Primary'].str.contains('kidney')].index
# Out:
# lung                                  187
# haematopoietic_and_lymphoid_tissue    181
# central_nervous_system                 69
# large_intestine                        62
# skin                                   62
# breast                                 60
# ovary                                  52
# pancreas                               46
# stomach                                38
# kidney                                 36
# upper_aerodigestive_tract              33
# bone                                   29
# liver                                  28
# endometrium                            28
# urinary_tract                          28
# oesophagus                             27
# soft_tissue                            21
# autonomic_ganglia                      17
# thyroid                                12
# pleura                                 11
# prostate                                8
# biliary_tract                           8
# salivary_gland                          2
# small_intestine                         1
# Name: Site Primary, dtype: int64

# %%
cnv = pd.read_pickle('data_large/CCLE_DEL_calls.pickle')
exp = pd.read_pickle('data/kidney_mrna_df.pickle')
exp.to_csv('data/kidney_DEL_calls_tab.gz', sep='\t', compression='gzip')
kidney_cells2 = list(set(exp.columns).intersection(cnv.columns))
cnv[kidney_cells2].to_csv('data/kidney_DEL_calls_df.gz', sep='\t', compression='gzip')

# %%
expdf, cnvdf = clv.load_data('data/kidney_DEL_calls_tab.gz', 'data/kidney_DEL_calls_df.gz')
# Out:
# mean:  2.1613484302624806
# std:  3.7810021582275386

# %%
expdf, cnvdf = clv.mainFitler(expdf, cnvdf, var=1, n=6)
# Out:
# exp: (15014, 36) --> filter --> (1988, 33)
# cnv: (23316, 33) --> filter --> (2729, 33)
# 5425252 CLOvE pairs are possible with these parameters
# estimated calculation time: 63.294606666666674min (~7sec/10k pairs)

# %%
kid_cloves_ccle = clv.randomPairContextStat(1000000, expdf, cnvdf, verbose=False, cat_df=False, nan_style='omit', permute=True)
# Out:
# attempting 1000000 of 5425252 total possible pairs post-filtering
# pair computation 10% complete (100000/5425252)
# pair computation 20% complete (200000/5425252)
# pair computation 30% complete (300000/5425252)
# pair computation 40% complete (400000/5425252)
# pair computation 50% complete (500000/5425252)
# pair computation 60% complete (600000/5425252)
# pair computation 70% complete (700000/5425252)
# pair computation 80% complete (800000/5425252)
# pair computation 90% complete (900000/5425252)
# pair computation 100% complete (1000000/5425252)

# %%
kid_cloves_ccle.to_csv('data/kidney_ttest_1M.tab.gz', compression='gzip', sep='\t')

# %% [markdown]
# ## FIX explicitpair to make all comparisons possible, add to list of list --> df and get timer

# %%
def explicitPairContextStat(expdf, cnvdf, exp_lis=False, cnv_lis=False, cat_df=False, nan_style='omit', permute=False):
    """
    takes exp and cnv genes (either all or explicitand returns pair summary statistics
    
    :param n_samp: int, number of random samples to take
    :param expdf: pandas dataframe, expression by sample 
                    (hopefully filtered with mainFilter, tissue specific, with matching samples in cnv)
    :param cnvdf: pandas dataframe, binarized mask 5(1=delete, 0=nodelete) deletion by sample 
                    (hopefully filtered with mainFilter, tissue specific, with matching samples in exp)
    :param exp_lis: list of str, HUGO gene names in expdf to restrict to, default is False (use all genes in expdf)
    :param exp_lis: list of str, HUGO gene names in cnvdf to restrict to, default is False (use all genes in cnvdf)
    :param in_df: pandas dataframe, previous calculations to concat new results to, used in while loop to get n_samp
    :param nan_style: str, how the stats.ttest_ind treats NANs, {‘propagate’, ‘raise’, ‘omit’}
    :param permute: bool, True will calculate pairs with randomly permuted expression matrix as null model
    
    returns df[['exp', 'cnv', 'cntxt_pos_mu', 'cntxt_neg_mu', 
                'cntxt_pos_var', 'cntxt_neg_var', 
                'cntxt_pos_n', 'cntxt_neg_n']]
    """
    exp_gene, cnv_gene, np_t_w, np_p_w, np_t_w_null, np_p_w_null = [], [], [],[], [], []
    cells = list(set(cnvdf.columns).intersection(expdf.columns))
    expdf = expdf[cells]
    cmask = cnvdf[cells] == 1
    if permute:
        cmask_n = scrambleDF(cmask)
    
    if type(exp_lis) != bool:
        exp_samp = set(expdf.index).intersection(exp_lis)
        for gene in exp_lis:
            if gene not in expdf.index:
                print('{} not found in expdf.index.  Omitted'.format(gene))
    else:
        exp_samp = expdf.index
    
    if type(cnv_lis) != bool:
        cnv_samp = set(cnvdf.index).intersection(cnv_lis)
        for gene in cnv_lis:
            if gene not in cnvdf.index:
                print('{} not found in cnvdf.index.  Omitted'.format(gene))
    else:
        cnv_samp = cnvdf.index
    print('attempting {} comparisons with current parameters'.format(len(exp_samp) * len(cnv_samp)))

    # progress initialize
    count=0
    percent_complete=0
    comparisons = df.shape[0]
    for pair in itertools.product(exp_samp, cnv_samp):
        exp, cnv = pair[0], pair[1]
        exp.append(pai)


    for row in df.itertuples():
        # progress report
        count+=1
        if count%(round(comparisons,-1)/10)==0:
            percent_complete+=10
            print('pair computation {}% complete ({}/{})'.format(percent_complete, count, comparisons))

        # mask cnv contexts onto expression data
        pos = np.array(expdf.loc[row.exp][cmask.loc[row.cnv]])
        neg = np.array(expdf.loc[row.exp][~cmask.loc[row.cnv]])

        if ((~np.isnan(pos)).sum() > min_n) &  ((~np.isnan(neg)).sum() > min_n):
            # calculate t_stat, welch
            t, p = stats.ttest_ind(pos, neg, nan_policy=nan_style, equal_var=True)
            np_t_w.append(t)
            np_p_w.append(p)
        else:    
            np_t_w.append(np.nan)
            np_p_w.append(np.nan)

        if permute:
            pos = np.array(expdf.loc[row.exp][cmask_n.loc[row.cnv]])
            neg = np.array(expdf.loc[row.exp][~cmask_n.loc[row.cnv]])
            if ((~np.isnan(pos)).sum() > min_n) &  ((~np.isnan(neg)).sum() > min_n):
                # calculate t_stat, welch
                t, p = stats.ttest_ind(pos, neg, nan_policy=nan_style, equal_var=True)
                np_t_w_null.append(t)
            else:    
                np_t_w_null.append(np.nan)

# %% [markdown]
# # Compute 1M Sample Breast CLOvE

# %%
# %matplotlib inline
expdf, cnvdf = load_data('data/breast_mrna.tab.gz', 'data/breast_CCLE_DEL_calls.csv.gz')

# %%
expdf, cnvdf = mainFitler(expdf, cnvdf, var=2, n=8)
# Out:
# exp: (16237, 59) --> filter --> (1688, 59)
# cnv: (23316, 59) --> filter --> (2278, 59)
# 3845264 CLOvE pairs are possible with these parameters
# estimated calculation time: 44.86141333333333min (~7sec/10k pairs)

# %%
matchdf = pd.read_csv('data/brca_1M_clove_pivot.tab.gz', compression='gzip', sep='\t', index_col=0)
matchdf
# %matplotlib inline
# bexp, bcnv = clv.load_data('data/lung_mrna_df.pickle', 'data/lung_cnv_df.p', details=True)
# Out:
#            A1BG  A1BG-AS1  A1CF  A2M  A2M-AS1     A2ML1  A2MP1  A3GALT2  \
# exp
# A1BG        NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# A1CF        NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# A2BP1       NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# A2LD1       NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# A2M         NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# A2ML1       NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# A4GALT      NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# A4GNT       NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# AAA1        NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# AAAS        NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# AACS        NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# AACSL       NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# AADAC       NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# AADACL2     NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# AADACL3     NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# AADACL4     NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# AADAT       NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# AAGAB       NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# AAK1        NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# AAMP        NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# AANAT       NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# AARS        NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# AARS2       NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# AARSD1      NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# AASDH       NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# AASDHPPT    NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# AASS        NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# AATF        NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# AATK        NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# ABAT        NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# ...         ...       ...   ...  ...      ...       ...    ...      ...
# ZSCAN2      NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# ZSCAN20     NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# ZSCAN21     NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# ZSCAN22     NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# ZSCAN23     NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# ZSCAN29     NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# ZSCAN4      NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# ZSCAN5A     NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# ZSCAN5B     NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# ZSWIM1      NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# ZSWIM2      NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# ZSWIM3      NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# ZSWIM4      NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# ZSWIM5      NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# ZSWIM6      NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# ZSWIM7      NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# ZUFSP       NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# ZW10        NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# ZWILCH      NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# ZWINT       NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# ZXDA        NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# ZXDB        NaN       NaN   NaN  NaN      NaN  0.012886    NaN      NaN
# ZXDC        NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# ZYG11A      NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# ZYG11B      NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# ZYX         NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# ZZEF1       NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# ZZZ3        NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# psiTPTE22   NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
# tAKR        NaN       NaN   NaN  NaN      NaN       NaN    NaN      NaN
#
#            A4GALT  A4GNT     ...      hsa-mir-664  hsa-mir-720  hsa-mir-886  \
# exp                          ...
# A1BG          NaN    NaN     ...              NaN          NaN          NaN
# A1CF          NaN    NaN     ...              NaN          NaN          NaN
# A2BP1         NaN    NaN     ...              NaN          NaN          NaN
# A2LD1         NaN    NaN     ...              NaN          NaN          NaN
# A2M           NaN    NaN     ...              NaN          NaN          NaN
# A2ML1         NaN    NaN     ...              NaN          NaN          NaN
# A4GALT        NaN    NaN     ...              NaN          NaN          NaN
# A4GNT         NaN    NaN     ...              NaN          NaN          NaN
# AAA1          NaN    NaN     ...              NaN          NaN          NaN
# AAAS          NaN    NaN     ...              NaN          NaN          NaN
# AACS          NaN    NaN     ...              NaN          NaN          NaN
# AACSL         NaN    NaN     ...              NaN          NaN          NaN
# AADAC         NaN    NaN     ...              NaN          NaN          NaN
# AADACL2       NaN    NaN     ...              NaN          NaN          NaN
# AADACL3       NaN    NaN     ...              NaN          NaN          NaN
# AADACL4       NaN    NaN     ...              NaN          NaN          NaN
# AADAT         NaN    NaN     ...              NaN          NaN          NaN
# AAGAB         NaN    NaN     ...              NaN          NaN          NaN
# AAK1          NaN    NaN     ...              NaN          NaN          NaN
# AAMP          NaN    NaN     ...              NaN          NaN          NaN
# AANAT         NaN    NaN     ...              NaN          NaN          NaN
# AARS          NaN    NaN     ...              NaN          NaN          NaN
# AARS2         NaN    NaN     ...              NaN          NaN          NaN
# AARSD1        NaN    NaN     ...              NaN          NaN          NaN
# AASDH         NaN    NaN     ...              NaN          NaN          NaN
# AASDHPPT      NaN    NaN     ...              NaN          NaN          NaN
# AASS          NaN    NaN     ...              NaN          NaN          NaN
# AATF          NaN    NaN     ...              NaN          NaN          NaN
# AATK          NaN    NaN     ...              NaN          NaN          NaN
# ABAT          NaN    NaN     ...              NaN          NaN          NaN
# ...           ...    ...     ...              ...          ...          ...
# ZSCAN2        NaN    NaN     ...              NaN          NaN          NaN
# ZSCAN20       NaN    NaN     ...              NaN          NaN          NaN
# ZSCAN21       NaN    NaN     ...              NaN          NaN          NaN
# ZSCAN22       NaN    NaN     ...              NaN          NaN          NaN
# ZSCAN23       NaN    NaN     ...              NaN          NaN          NaN
# ZSCAN29       NaN    NaN     ...              NaN          NaN          NaN
# ZSCAN4        NaN    NaN     ...              NaN          NaN          NaN
# ZSCAN5A       NaN    NaN     ...              NaN          NaN          NaN
# ZSCAN5B       NaN    NaN     ...              NaN          NaN          NaN
# ZSWIM1        NaN    NaN     ...              NaN          NaN          NaN
# ZSWIM2        NaN    NaN     ...              NaN          NaN          NaN
# ZSWIM3        NaN    NaN     ...              NaN          NaN          NaN
# ZSWIM4        NaN    NaN     ...              NaN          NaN          NaN
# ZSWIM5        NaN    NaN     ...              NaN          NaN          NaN
# ZSWIM6        NaN    NaN     ...              NaN          NaN          NaN
# ZSWIM7        NaN    NaN     ...              NaN          NaN          NaN
# ZUFSP         NaN    NaN     ...              NaN          NaN          NaN
# ZW10          NaN    NaN     ...              NaN          NaN          NaN
# ZWILCH        NaN    NaN     ...              NaN          NaN          NaN
# ZWINT         NaN    NaN     ...              NaN          NaN          NaN
# ZXDA          NaN    NaN     ...              NaN          NaN          NaN
# ZXDB          NaN    NaN     ...              NaN          NaN          NaN
# ZXDC          NaN    NaN     ...              NaN          NaN          NaN
# ZYG11A        NaN    NaN     ...              NaN          NaN          NaN
# ZYG11B        NaN    NaN     ...              NaN          NaN          NaN
# ZYX           NaN    NaN     ...              NaN          NaN          NaN
# ZZEF1         NaN    NaN     ...              NaN          NaN          NaN
# ZZZ3          NaN    NaN     ...              NaN          NaN          NaN
# psiTPTE22     NaN    NaN     ...              NaN          NaN          NaN
# tAKR          NaN    NaN     ...              NaN          NaN          NaN
#
#            hsa-mir-887  hsa-mir-924  hsa-mir-941-1  hsa-mir-941-2  \
# exp
# A1BG               NaN          NaN            NaN            NaN
# A1CF               NaN          NaN            NaN            NaN
# A2BP1              NaN          NaN            NaN            NaN
# A2LD1              NaN          NaN            NaN            NaN
# A2M                NaN          NaN            NaN            NaN
# A2ML1              NaN          NaN         2.2253            NaN
# A4GALT             NaN          NaN            NaN            NaN
# A4GNT              NaN          NaN            NaN            NaN
# AAA1               NaN          NaN            NaN            NaN
# AAAS               NaN          NaN            NaN            NaN
# AACS               NaN          NaN            NaN            NaN
# AACSL              NaN          NaN            NaN            NaN
# AADAC              NaN          NaN            NaN            NaN
# AADACL2            NaN          NaN            NaN            NaN
# AADACL3            NaN          NaN            NaN            NaN
# AADACL4            NaN          NaN            NaN            NaN
# AADAT              NaN          NaN            NaN            NaN
# AAGAB              NaN          NaN            NaN            NaN
# AAK1               NaN          NaN            NaN            NaN
# AAMP               NaN          NaN            NaN            NaN
# AANAT              NaN          NaN            NaN            NaN
# AARS               NaN          NaN            NaN            NaN
# AARS2              NaN          NaN            NaN            NaN
# AARSD1             NaN          NaN            NaN            NaN
# AASDH              NaN          NaN            NaN            NaN
# AASDHPPT           NaN          NaN            NaN            NaN
# AASS               NaN          NaN            NaN            NaN
# AATF               NaN          NaN            NaN            NaN
# AATK               NaN          NaN            NaN            NaN
# ABAT               NaN          NaN            NaN            NaN
# ...                ...          ...            ...            ...
# ZSCAN2             NaN          NaN            NaN            NaN
# ZSCAN20            NaN          NaN            NaN            NaN
# ZSCAN21            NaN          NaN            NaN            NaN
# ZSCAN22            NaN          NaN            NaN            NaN
# ZSCAN23            NaN          NaN            NaN            NaN
# ZSCAN29            NaN          NaN            NaN            NaN
# ZSCAN4             NaN          NaN            NaN            NaN
# ZSCAN5A            NaN          NaN            NaN            NaN
# ZSCAN5B            NaN          NaN            NaN            NaN
# ZSWIM1             NaN          NaN            NaN            NaN
# ZSWIM2             NaN          NaN            NaN            NaN
# ZSWIM3             NaN          NaN            NaN            NaN
# ZSWIM4             NaN          NaN            NaN            NaN
# ZSWIM5             NaN          NaN            NaN            NaN
# ZSWIM6             NaN          NaN            NaN            NaN
# ZSWIM7             NaN          NaN            NaN            NaN
# ZUFSP              NaN          NaN            NaN            NaN
# ZW10               NaN          NaN            NaN            NaN
# ZWILCH             NaN          NaN            NaN            NaN
# ZWINT              NaN          NaN            NaN            NaN
# ZXDA               NaN          NaN            NaN            NaN
# ZXDB               NaN          NaN            NaN            NaN
# ZXDC               NaN          NaN            NaN            NaN
# ZYG11A             NaN          NaN            NaN            NaN
# ZYG11B             NaN          NaN            NaN            NaN
# ZYX                NaN          NaN            NaN            NaN
# ZZEF1              NaN          NaN            NaN            NaN
# ZZZ3               NaN          NaN            NaN            NaN
# psiTPTE22          NaN          NaN            NaN            NaN
# tAKR               NaN          NaN            NaN            NaN
#
#            hsa-mir-941-3  hsa-mir-95  hsa-mir-96
# exp
# A1BG                 NaN         NaN         NaN
# A1CF                 NaN         NaN         NaN
# A2BP1                NaN         NaN         NaN
# A2LD1                NaN         NaN         NaN
# A2M                  NaN         NaN         NaN
# A2ML1                NaN         NaN         NaN
# A4GALT               NaN         NaN         NaN
# A4GNT                NaN         NaN         NaN
# AAA1                 NaN         NaN         NaN
# AAAS                 NaN         NaN         NaN
# AACS                 NaN         NaN         NaN
# AACSL                NaN         NaN         NaN
# AADAC                NaN         NaN         NaN
# AADACL2              NaN         NaN         NaN
# AADACL3              NaN         NaN         NaN
# AADACL4              NaN         NaN         NaN
# AADAT                NaN         NaN         NaN
# AAGAB                NaN         NaN         NaN
# AAK1                 NaN         NaN         NaN
# AAMP                 NaN         NaN         NaN
# AANAT                NaN         NaN         NaN
# AARS                 NaN         NaN         NaN
# AARS2                NaN         NaN         NaN
# AARSD1               NaN         NaN         NaN
# AASDH                NaN         NaN         NaN
# AASDHPPT             NaN         NaN         NaN
# AASS                 NaN         NaN         NaN
# AATF                 NaN         NaN         NaN
# AATK                 NaN         NaN         NaN
# ABAT                 NaN         NaN         NaN
# ...                  ...         ...         ...
# ZSCAN2               NaN         NaN         NaN
# ZSCAN20              NaN         NaN         NaN
# ZSCAN21              NaN         NaN         NaN
# ZSCAN22              NaN         NaN         NaN
# ZSCAN23              NaN         NaN         NaN
# ZSCAN29              NaN         NaN         NaN
# ZSCAN4               NaN         NaN         NaN
# ZSCAN5A              NaN         NaN         NaN
# ZSCAN5B              NaN         NaN         NaN
# ZSWIM1               NaN         NaN         NaN
# ZSWIM2               NaN         NaN         NaN
# ZSWIM3               NaN         NaN         NaN
# ZSWIM4               NaN         NaN         NaN
# ZSWIM5               NaN         NaN         NaN
# ZSWIM6               NaN         NaN         NaN
# ZSWIM7               NaN         NaN         NaN
# ZUFSP                NaN         NaN         NaN
# ZW10                 NaN         NaN         NaN
# ZWILCH               NaN         NaN         NaN
# ZWINT                NaN         NaN         NaN
# ZXDA                 NaN         NaN         NaN
# ZXDB                 NaN         NaN         NaN
# ZXDC                 NaN         NaN         NaN
# ZYG11A               NaN         NaN         NaN
# ZYG11B               NaN         NaN         NaN
# ZYX                  NaN         NaN         NaN
# ZZEF1                NaN         NaN         NaN
# ZZZ3                 NaN         NaN         NaN
# psiTPTE22            NaN         NaN         NaN
# tAKR                 NaN         NaN         NaN
#
# [20221 rows x 25128 columns]

# %% [markdown]
# ## graph distribution of copy numer in LUNG CCLE

# %%
calls = pd.read_pickle('data_large/CCLE_DEL_calls.pickle')
cellinfo = pd.read_pickle('data_large/ccle_cell_info_df.pickle')
lungcnv = pd.read_pickle('data/lung_cnv_df.pickle')
lungexp = pd.read_pickle('data/lung_mrna_df.pickle')

# %%
lungexp1, lungcnv1  = clv.ccleTissueSelect(expdf_fn='data/lung_mrna_df.pickle',
                                         cnvdf_fn='data_large/CCLE_DEL_calls.pickle',
                                         celldf_fn='data_large/ccle_cell_info_df.pickle',
                                         tissue='lung', out_dir='data/')

# %%
# %matplotlib inline
clv.graph_n_ratio(lungcnv1, 'lung', y0=2250, yd=150)
# Out:
# mean:  0.0003419580682746488
# std:  0.0004864900226009831

# %%
clv.graph_n_dist(lungcnv1, tissue='lung', y0=0.09, yd=0.02)
# Out:
# mean:  7.964873906330417
# std:  11.298861660411463

# %%
exp_arr = lungexp.values.flatten()
exp_arr =exp_arr[~np.isnan(exp_arr)]
print('mean: ', np.mean(exp_arr))
print('std: ', np.std(exp_arr))
sns.distplot(exp_arr, hist=False, color='black')
plt.title('lung expression distribition, ccle')
# Out:
# mean:  7.96913214053
# std:  2.00143772104

# %%
exp_cnv = lungcnv.values.flatten()
exp_cnv =exp_cnv[~np.isnan(exp_cnv)]
print('mean: ', np.mean(exp_cnv))
print('std: ', np.std(exp_cnv))
sns.distplot(exp_cnv, hist=False, color='black')
plt.title('lung copy distribition, ccle')
# Out:
# mean:  0.00664955547931
# std:  0.455208235057

# %% [markdown]
# ## compare GISTIC log2 values with REVEALER calls

# %%
gistic = pd.read_pickle('data/lung_cnv_df.pickle')
lungexp, reveal = clv.ccleTissueSelect(expdf_fn='data/lung_mrna_df.pickle',
                                         cnvdf_fn='data_large/CCLE_DEL_calls.pickle',
                                         celldf_fn='data_large/ccle_cell_info_df.pickle',
                                         tissue='lung', out_dir='data/')

# %%
print(gistic.shape)
gistic.head(1)
# Out:
# (23316, 180)
#         A549_LUNG  ABC1_LUNG  BEN_LUNG  CAL12T_LUNG  CALU1_LUNG  CALU3_LUNG  \
# SYMBOL
# A1BG       0.4405     0.7541    0.1362      -0.3696     -0.3462      0.3349
#
#         CALU6_LUNG  CHAGOK1_LUNG  COLO668_LUNG  CORL105_LUNG      ...       \
# SYMBOL                                                            ...
# A1BG        0.2393        0.3836       -0.5689        0.3113      ...
#
#         SKLU1_LUNG  SKMES1_LUNG  SQ1_LUNG  SW1271_LUNG  SW1573_LUNG  \
# SYMBOL
# A1BG       -0.0661       0.2115   -0.4725        -0.24      -0.1081
#
#         SW900_LUNG  T3M10_LUNG  TIG3TD_LUNG  VMRCLCD_LUNG  VMRCLCP_LUNG
# SYMBOL
# A1BG        0.1534      0.1002       0.0199        -0.192        0.6702
#
# [1 rows x 180 columns]

# %%
print(reveal.shape)
reveal.head(1)
# Out:
# (23316, 181)
#       HCC366_LUNG  NCIH661_LUNG  NCIH727_LUNG  RERFLCAI_LUNG  NCIH2029_LUNG  \
# Name
# A1BG            0             0             0              0              0
#
#       DMS273_LUNG  LXF289_LUNG  HS618T_LUNG  NCIH1930_LUNG  IALM_LUNG  \
# Name
# A1BG            0            0            0              0          0
#
#         ...      NCIH2085_LUNG  NCIH2023_LUNG  NCIH2342_LUNG  NCIH226_LUNG  \
# Name    ...
# A1BG    ...                  0              0              0             0
#
#       NCIH510_LUNG  NCIH2066_LUNG  NCIH1734_LUNG  LUDLU1_LUNG  NCIH2106_LUNG  \
# Name
# A1BG             0              0              0            0              0
#
#       SALE_LUNG
# Name
# A1BG          0
#
# [1 rows x 181 columns]

# %%
l = pd.DataFrame(reveal.stack()).reset_index()
l.columns = ['gene','cell','reveler_del']
r = pd.DataFrame(gistic.stack()).reset_index()
r.columns = ['gene','cell','gistic_val']
rev_gis_merge = pd.merge(left=l, right=r, left_on=['gene','cell'], right_on=['gene','cell'])

# %%
pal = {0: "gray", 1: "red"}

# %%
pal = {0: "gray", 1: "red"}

tt = stats.ttest_ind(rev_gis_merge[rev_gis_merge['reveler_del']==0]['gistic_val'],
                rev_gis_merge[rev_gis_merge['reveler_del']==1]['gistic_val'])
print(tt)
# %matplotlib inline
sns.set_style('white')
sns.violinplot(data=rev_gis_merge, x='reveler_del', y='gistic_val', palette=pal)
sns.despine()
# Out:
# Ttest_indResult(statistic=1351.1892119949173, pvalue=0.0)

# %%
# from cloveFunctions import *

def matchPairContextStat(expdf, cnvdf, new_cohort, matchdf, match_cohort, nan_style='omit', permute=False):
    """
    computes clove pairs from one sample that match with those computed in some other cohorts
    
    :param expdf: pandas dataframe, expression by sample 
                    (hopefully filtered with mainFilter, tissue specific, with matching samples in cnv)
    :param cnvdf: pandas dataframe, binarized mask 5(1=delete, 0=nodelete) deletion by sample 
                    (hopefully filtered with mainFilter, tissue specific, with matching samples in exp)
    :param new_cohort: str, identifier for the current cohort computation (eg, tissue origin of exp and cnv)
    :param matchdf: pandas dataframe, results of clove computation performed in other cohort
                    exp and cnv pairs will be used to populate the new clove results so pairs match between cohort
    :param match_cohort: str, identifier for the matching (precomputed) cohort used (eg, tissue origin of matchdf)
    :param nan_style: str, how the stats.ttest_ind treats NANs, {‘propagate’, ‘raise’, ‘omit’}
    :param permute: bool, True will calculate pairs with randomly permuted expression matrix as null model
    
    returns df[['exp', 'cnv', 'cntxt_pos_mu', 'cntxt_neg_mu', 
                'cntxt_pos_var', 'cntxt_neg_var', 
                'cntxt_pos_n', 'cntxt_neg_n']]
    """
    
    cells = list(set(cnvdf.columns).intersection(expdf.columns)) # confirm same samples in both cnv and exp
    expdf = expdf[cells]
    cmask = cnvdf[cells] == 1
    
    df = matchdf[['exp', 'cnv', 'np_t_w', 'np_t_w_null','np_p_w']]
    df.columns = ['exp', 'cnv', 't_'+match_cohort, 't_null_'+match_cohort, 'p_'+match_cohort,]
    
    if permute:
        cmask_n = scrambleDF(cmask)
    
#     only keep elements of matchdf['exp'] that are also in expdf.index
    df = df[(df['exp'].isin(expdf.index)) & (df['cnv'].isin(cnvdf.index))]
    print('attempting {} comparisons referenced from {}'.format(df.shape[0], match_cohort))
    
    np_t_w, np_p_w, np_t_w_null = [], [], []
  
    # progress initialize
    count=0
    percent_complete=0
    comparisons = df.shape[0]
    
    for row in df.itertuples():
        # progress report
        count+=1
        if count%(comparisons/10)==0:
            print('hiii')
            print(np.array(expdf.loc[row.exp][cmask.loc[row.cnv]]))
            percent_complete+=10
            print('pair computation {}% complete ({}/{})'.format(percent_complete, count, comparisons))
        
        # mask cnv contexts onto expression data
        pos = np.array(expdf.loc[row.exp][cmask.loc[row.cnv]])
        neg = np.array(expdf.loc[row.exp][~cmask.loc[row.cnv]])
        
        # calculate t_stat, welch
        t, p = stats.ttest_ind(pos, neg, nan_policy=nan_style, equal_var=True)
        if type(np_t_w) == np.ma.core.MaskedConstant:
            print('its masked')
            print([pos, neg])
            np_t_w.append(np.nan)
            np_p_w.append(np.nan)
        else:    
            np_t_w.append(t)
            np_p_w.append(p)
        
        if permute:
            pos = np.array(expdf.loc[row.exp][cmask_n.loc[row.cnv]])
            neg = np.array(expdf.loc[row.exp][~cmask_n.loc[row.cnv]])
            t, p = stats.ttest_ind(pos, neg, nan_policy=nan_style, equal_var=True)
            np_t_w_null.append(t)
   
    df['t_'+new_cohort] = np_t_w
    df['p_'+new_cohort] = np_p_w
    
    if permute:
        df['t_null_'+new_cohort] = np_t_w_null
        
    return df, np_t_w

# %% [markdown]
# ## Compute Some Sample Lung CLOvE matching pre-computed TCGA values

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
import cloveFunctions as clv
import matplotlib
# matplotlib.use('Qt4Agg')
import matplotlib.pyplot as plt
# matplotlib.rcParams['figure.figsize'] = (20.0, 10.0)
import warnings
warnings.filterwarnings('ignore')

# %%
# bring in exp and cnv data from
# G:\My Drive\Python Scripts\clove\tissueDF_raw

matchdf = pd.read_csv('data/tcga_lung_cloves.tab.gz', compression='gzip', sep='\t', index_col=0)
# %matplotlib inline
lungexp, lungcnv = clv.load_data('data/lung_mrna_df.pickle', 'data/lung_cnv_df.p', details=True)
# Out:
# mean:  7.964873906330417
# std:  11.298861660411463

# %%
v_min, n_min = 2, 2
lungexp, lungcnv = clv.mainFitler(lungexp, lungcnv, var=v_min, n=n_min)
# Out:
# exp: (17380, 186) --> filter --> (2030, 180)
# cnv: (23316, 181) --> filter --> (18312, 180)
# 37173360 CLOvE pairs are possible with these parameters
# estimated calculation time: 433.68919999999997min (~7sec/10k pairs)

# %%
lungresults = clv.matchPairContextStat(lungexp, lungcnv, 'ccle_lung', matchdf, 'tcga_lung', nan_style='omit', min_var=v_min, min_n=n_min, permute=False)
# Out:
# attempting 50612 comparisons referenced from tcga_lung (var>2, n>2
# pair computation 10% complete (5061/50612)
# pair computation 20% complete (10122/50612)
# pair computation 30% complete (15183/50612)
# pair computation 40% complete (20244/50612)
# pair computation 50% complete (25305/50612)
# pair computation 60% complete (30366/50612)
# pair computation 70% complete (35427/50612)
# pair computation 80% complete (40488/50612)
# pair computation 90% complete (45549/50612)
# pair computation 100% complete (50610/50612)
# 50612

# %%
lungresults.to_csv('data/tcga_v_ccle_lung.tab.gz', sep='\t', compression='gzip')

# %% [markdown]
# To Do
# Debug matchPairContextStat func in tgca_vs_ccle.ipynb
# Add save parameter
# Run above func to compute CCLE lung matching pairs in data/tcga_lung_cloves.tab.gz
# Write function to Graph Scatter (with 3𝞭 cutoff)
# Graph above func for lung CCLE vs TCGA
# Run millions of comparisons in TCGA BRCA
# Re-run millions of comparisons in CCLE breast?
# If not, use existing CCLE breast cloves to dictate which pairs tested
# Run millions of comparisons in TCGA BRCA
# Housekeeping
# Func load_data created to handle raw input files directly
# Relies on Func graph_var_dist and graph_n_dist to display summary stats n and var for use in filtering
# TODO add in tissue/cohort subset option
# Func matchPairContextStat computes pairs in new data according to pairs defined in old data.  Used to match pair for pair across each cohort
# TODO test/debug in ccle_sandbox

# %% [markdown]
# WHY ARE THERE SO MANY -- IN MY DATA?

# %%
lungresults.dropna()
# Out:
#             exp        cnv  t_tcga_lung   p_tcga_lung  t_ccle_lung  \
# 856        BCHE       APOD     2.232715  2.579047e-02    -1.011340
# 863        BCHE    TAS2R20     3.081984  2.113071e-03     0.505528
# 865        BCHE   TMEM120A     1.182565  2.372653e-01     0.235038
# 880        BCHE     CT45A3     1.159753  2.464288e-01     0.255718
# 905        BCHE      THAP7     4.098205  4.504141e-05     1.431856
# 906      RASSF6     CT47A7    -1.100798  2.712521e-01     0.386493
# 912      RASSF6       CCL5    -3.415620  6.621911e-04    -0.354742
# 917      RASSF6       SOX5     0.185942  8.525280e-01     0.593309
# 927      RASSF6      RFPL1    -0.272796  7.850665e-01    -0.852622
# 934      RASSF6     RNF182    -2.127327  3.363938e-02     0.521989
# 943      RASSF6   TBC1D3P5    -2.018246  4.383465e-02     0.652521
# 956      RASSF6      RSPO2    -0.217928  8.275300e-01    -0.785517
# 958      RASSF6    GPATCH2    -3.124772  1.831170e-03     0.507959
# 963      RASSF6   PPAPDC1B    -0.121505  9.033157e-01    -0.952767
# 967      RASSF6       TWF1    -0.587030  5.573173e-01    -1.215982
# 969      RASSF6       PLD5    -2.717644  6.689523e-03    -1.182219
# 970      RASSF6  LINC00086    -1.345617  1.787339e-01    -0.075318
# 1212      DPP10      CPXM1     1.699432  8.955156e-02    -1.030463
# 1216      DPP10     PGRMC1     3.314667  9.507750e-04    -0.185003
# 1218      DPP10     TXNDC5     1.731416  8.368877e-02    -0.715477
# 1219      DPP10    CXorf56     3.105927  1.950765e-03    -0.185003
# 1220      DPP10       TESC     0.331053  7.406741e-01     1.544939
# 1228      DPP10     DIAPH2     3.526106  4.410235e-04    -0.446023
# 1236      DPP10     BCORL1     3.060196  2.271450e-03    -0.942832
# 1239      DPP10    SLC24A3     2.744505  6.169745e-03    -1.157310
# 1241      DPP10     MOSPD1     2.851142  4.446668e-03    -0.942832
# 1246      DPP10     RB1CC1     0.695035  4.871961e-01     0.021727
# 1249      DPP10      UBE3C    -1.224451  2.210730e-01    -2.271672
# 1251      DPP10     NPBWR1     0.651279  5.150174e-01     0.021727
# 1634      NRCAM      WNT5B     6.242904  6.359863e-10     1.942676
# ...         ...        ...          ...           ...          ...
# 998876  PCOLCE2      LYPD6     1.107761  2.682339e-01     0.094717
# 998878  PCOLCE2    EFCAB4B     3.634492  2.928382e-04     0.082047
# 998883  PCOLCE2      HEXDC     0.723342  4.696406e-01     1.968162
# 998885  PCOLCE2        LEP    -0.328224  7.428118e-01     0.104539
# 998888  PCOLCE2      MUC17     0.593480  5.529955e-01     0.447740
# 998896  PCOLCE2      ASH2L     2.543379  1.112960e-02    -0.044378
# 998901  PCOLCE2      IMPA1     0.302175  7.625822e-01     1.167399
# 998904  PCOLCE2      VGLL1     1.987673  4.712276e-02    -0.975782
# 998906  PCOLCE2  LOC401463     0.562048  5.742102e-01     0.154192
# 998909  PCOLCE2     EDDM3B     0.062511  9.501686e-01     0.279062
# 998911  PCOLCE2       PRB2     3.935682  8.875355e-05     0.175160
# 998912  PCOLCE2    RNF113A     2.252961  2.447963e-02    -1.372705
# 998913  PCOLCE2     UGT3A2     2.617037  9.004749e-03     0.585341
# 999101    EPCAM      TULP1     3.437942  6.105299e-04     0.681406
# 999103    EPCAM     CLPSL1     3.425672  6.384425e-04     0.681406
# 999105    EPCAM      MIR96     2.745300  6.154937e-03    -1.448087
# 999107    EPCAM    C2orf48     5.014232  6.305937e-07     0.808320
# 999110    EPCAM      PRSS1     3.195987  1.437599e-03    -1.448087
# 999112    EPCAM  WDR86-AS1     2.925008  3.522971e-03    -1.900630
# 999114    EPCAM       FRS3     3.220287  1.322279e-03     0.681406
# 999115    EPCAM      LYPD1     5.116367  3.739234e-07     1.036906
# 999118    EPCAM      ABCF2     3.037472  2.448183e-03    -1.421747
# 999120    EPCAM     ZNHIT3     8.899770  2.613765e-18     0.332213
# 999128    EPCAM   MIR548A1     4.058052  5.337695e-05    -0.550035
# 999132    EPCAM    SLC23A2    -2.688075  7.307026e-03     0.285233
# 999135    EPCAM       CUL9     3.074485  2.166397e-03     0.681406
# 999136    EPCAM       CPA4     2.916369  3.621154e-03    -1.448087
# 999138    EPCAM      FITM1     0.906148  3.650778e-01    -1.134949
# 999142    EPCAM     HRSP12     0.098356  9.216694e-01     0.634186
# 999144    EPCAM        OSM    -5.432958  6.976084e-08     0.580591
#
#         p_ccle_lung
# 856        0.315547
# 863        0.614872
# 865        0.814907
# 880        0.798964
# 905        0.156904
# 906        0.699852
# 912        0.723438
# 917        0.554150
# 927        0.395657
# 934        0.602691
# 943        0.515379
# 956        0.433780
# 958        0.612463
# 963        0.342724
# 967        0.226504
# 969        0.239579
# 970        0.940093
# 1212       0.306554
# 1216       0.853794
# 1218       0.476838
# 1219       0.853794
# 1220       0.127143
# 1228       0.657041
# 1236       0.349205
# 1239       0.251317
# 1241       0.349205
# 1246       0.982731
# 1249       0.026373
# 1251       0.982731
# 1634       0.054733
# ...             ...
# 998876     0.924660
# 998878     0.934714
# 998883     0.050811
# 998885     0.916875
# 998888     0.654958
# 998896     0.964660
# 998901     0.244819
# 998904     0.330674
# 998906     0.877657
# 998909     0.780565
# 998911     0.861179
# 998912     0.171802
# 998913     0.559159
# 999101     0.496558
# 999103     0.496558
# 999105     0.149468
# 999107     0.420056
# 999110     0.149468
# 999112     0.059073
# 999114     0.496558
# 999115     0.301279
# 999118     0.156964
# 999120     0.740145
# 999128     0.583030
# 999132     0.775819
# 999135     0.496558
# 999136     0.149468
# 999138     0.258023
# 999142     0.526827
# 999144     0.562299
#
# [15755 rows x 6 columns]

# %%
lungresults.to_csv('data/tcga_v_ccle_lung.tab.gz', sep='\t', compression='gzip')
# lungresults = pd.read_csv('data/tcga_v_ccle_lung.tab.gz', sep='\t', compression='gzip', index_col=0)

# %%
lungresults[lungresults['t_ccle_lung'] == np.ma.core.MaskedConstant]
# Out:
# Empty DataFrame
# Columns: [exp, cnv, t_tcga_lung, t_null_tcga_lung, p_tcga_lung, t_ccle_lung, p_ccle_lung]
# Index: []

# %% [markdown]
# GRAPH LUNG CCLE vs TCGA 3sig

# %%
# lungresults.to_csv('data/tcga_v_ccle_lung.tab.gz', sep='\t', compression='gzip')
lungresults = pd.read_csv('data/tcga_v_ccle_lung.tab.gz', sep='\t', compression='gzip', index_col=0)

# %%
# %matplotlib inline

def graph_clove_clove(df=lungresults, x='t_ccle_lung', y='t_tcga_lung'):
    s1_ccle = np.std(df[x])*1.5
    s1_tcga = np.std(df[y])*1.5

    sns.set_style("white")
    sns.scatterplot(x=df[x], y=df[y])
    plt.plot([s1_ccle,s1_ccle], [df[y].max(), df[y].min()], linestyle='dotted', color='gray')
    plt.plot([df[x].max(), df[x].min()],[s1_tcga,s1_tcga],  linestyle='dotted', color='gray')
    sns.despine()
    
    df = df[(df[y]>s1_tcga) & (lungresults[x]>s1_ccle)]
    df['prod'] = df[x] * df[y]
    
    return df.sort_values(by='prod', ascending=False)

def table_clove_clove(df=lungresults, x='t_ccle_lung', y='t_tcga_lung'):
    s1_ccle = np.std(df[x])*1.5
    s1_tcga = np.std(df[y])*1.5

    return df[(df[y]>s1_tcga) & (lungresults[x]>s1_ccle)]

lung = graph_clove_clove()

# %%
lung
# Out:
#             exp        cnv  t_tcga_lung   p_tcga_lung  t_ccle_lung  \
# 871390    MATN2      P2RX6     5.624647  2.417490e-08     4.014808
# 747820   FERMT1     GSTTP1     8.747412  9.233116e-18     2.100874
# 871402    MATN2     ZDHHC8     5.624647  2.417490e-08     3.118817
# 391312    ITGB5      CLDN5     7.201381  1.177691e-12     2.034270
# 168823    CSRP2    ZDHHC19     8.373404  1.893301e-16     1.723356
# 147616      SFN      RTDR1     8.019258  2.984272e-15     1.755211
# 947226    ITGA6     CRNKL1     5.327829  1.230366e-07     2.421712
# 1634      NRCAM      WNT5B     6.242904  6.359863e-10     1.942676
# 391282    ITGB5     GAS2L1     6.815004  1.634475e-11     1.707531
# 434078    INHBE    TAS2R30     3.768095  1.742044e-04     3.058910
# 443494     AHRR      CETN1     4.449684  9.573836e-06     2.340997
# 95424     DFNA5       GNAZ     3.935846  8.869362e-05     2.517277
# 958244    FRMD6       GZMH     4.764581  2.175098e-06     2.013916
# 958232    FRMD6    MIR4307     4.743823  2.404905e-06     2.000572
# 14134      FZD7      TSHZ3     4.406334  1.165875e-05     2.105621
# 505313   CYB5R2       PRB1     4.675509  3.337785e-06     1.960283
# 505266   CYB5R2       EMP1     4.827595  1.599702e-06     1.895807
# 569033     ZIC2     MIR141     4.336431  1.596161e-05     2.108845
# 498780     GNG4       LTBR     3.453762  5.762177e-04     2.540981
# 68484     SRXN1       PON1     4.874019  1.272747e-06     1.722585
# 95444     DFNA5     SCARF2     3.443806  5.975944e-04     2.427493
# 408299   PHLDA1        LPP     4.366589  1.394616e-05     1.902620
# 653516   GRAMD3     PRRC2A     3.519512  4.519913e-04     2.329498
# 391273    ITGB5       JAG1     4.021930  6.210881e-05     2.031679
# 15157   SMARCA1    PDE4DIP     5.182951  2.646310e-07     1.570582
# 947207    ITGA6      SIRPG     5.162329  2.946636e-07     1.572159
# 28319    PRSS23       TTC5     3.588720  3.485712e-04     2.252994
# 135986  RASSF10      PPIL1     3.316807  9.436032e-04     2.395056
# 498793     GNG4    TAS2R19     3.889370  1.072071e-04     2.000868
# 142344  JAKMIP2    MIR200C     3.838421  1.316747e-04     1.999424
# 664921  CNTNAP2    TAS2R13     4.829731  1.583031e-06     1.574721
# 357625    OLFM1     CLEC2D     4.146135  3.670769e-05     1.831555
# 106985      TNC    MIR208A     3.494011  4.968590e-04     2.161860
# 875726    TGFBI       MDP1     3.235540  1.254321e-03     2.331881
# 587143     MYLK       GGT1     3.225640  1.298053e-03     2.338952
# 717392    NCEH1      SLFN5     3.715485  2.141521e-04     2.030020
# 964232     IER3       SCGN     4.178057  3.199469e-05     1.732828
# 897675  FAM110C      PSMF1     4.213807  2.740102e-05     1.718092
# 391299    ITGB5    DEFB125     3.685707  2.404305e-04     1.944989
# 963493   AGPAT9      RSPO4     3.880309  1.112184e-04     1.845177
# 106970      TNC      PARP2     3.246293  1.208374e-03     2.173488
# 664928  CNTNAP2  GABARAPL1     4.478651  8.384955e-06     1.574721
# 642986      ME1   MIR153-2     4.306315  1.824999e-05     1.605878
# 914012    ALPK2     ACAD11     3.207517  1.381768e-03     2.098187
# 176024     SGK1     EHHADH     3.368398  7.851734e-04     1.946031
# 968091    LYPD3      MECOM     3.331781  8.948061e-04     1.841477
# 429011      ADM     PMS2P1     3.448204  5.880626e-04     1.771964
# 846551    MAP1B       M6PR     3.276882  1.086040e-03     1.834034
# 347043   HOXC10    SLC7A13     3.620772  3.085990e-04     1.641788
# 992540   TRIM59       PSG9     3.596272  3.387386e-04     1.649792
# 95453     DFNA5      PATZ1     3.553559  3.979734e-04     1.655597
# 410629    SFTA3      GCNT2     3.550754  4.021857e-04     1.634982
# 447184    LAMC2       NAPB     3.516488  4.571072e-04     1.645947
# 639176  ALDH1A1      WDR88     3.349556  8.399251e-04     1.671890
# 255758    DDX3Y     CLECL1     3.313420  9.549793e-04     1.671083
# 646291   HRASLS      DPPA3     3.332989  8.909740e-04     1.626403
#
#         p_ccle_lung       prod
# 871390     0.000090  22.581877
# 747820     0.037163  18.377214
# 871402     0.002137  17.542244
# 391312     0.043526  14.649554
# 168823     0.086611  14.430355
# 147616     0.080944  14.075490
# 947226     0.016499  12.902468
# 1634       0.054733  12.127941
# 391282     0.089604  11.636830
# 434078     0.002935  11.526264
# 443494     0.020604  10.416698
# 95424      0.013071   9.907616
# 958244     0.045624   9.595465
# 958232     0.047059   9.490361
# 14134      0.036733   9.278071
# 505313     0.053444   9.165319
# 505266     0.061597   9.152191
# 569033     0.036631   9.144863
# 498780     0.012211   8.775943
# 68484      0.086837   8.395911
# 95444      0.016606   8.359816
# 408299     0.058723   8.307958
# 653516     0.021204   8.198697
# 391273     0.043790   8.171272
# 15157      0.118096   8.140251
# 947207     0.117773   8.115999
# 28319      0.025569   8.085365
# 135986     0.018205   7.943940
# 498793     0.047458   7.782117
# 142344     0.049234   7.674632
# 664921     0.119830   7.605477
# 357625     0.070605   7.593874
# 106985     0.032550   7.553564
# 875726     0.021187   7.544896
# 587143     0.020590   7.544616
# 717392     0.043860   7.542507
# 964232     0.084919   7.239853
# 897675     0.088672   7.239709
# 391299     0.053476   7.168657
# 963493     0.066997   7.159857
# 106970     0.031644   7.055778
# 664928     0.119830   7.052624
# 642986     0.110179   6.915417
# 914012     0.040765   6.729970
# 176024     0.053340   6.555006
# 968091     0.070496   6.135398
# 429011     0.078181   6.110094
# 846551     0.068387   6.009912
# 347043     0.104163   5.944540
# 992540     0.100911   5.933100
# 95453      0.100272   5.883263
# 410629     0.106607   5.805418
# 447184     0.102578   5.787951
# 639176     0.098405   5.600087
# 255758     0.099666   5.536999
# 646291     0.106129   5.420782

# %%
kid_cloves_ccle = pd.read_csv('data/kidney_ttest_1M.tab.gz', compression='gzip', sep='\t')
kid_cloves_tcga = pd.read_csv('data/tcga_kidney_cloves.tab.gz', compression='gzip', sep='\t')

# %%
kid_cloves_ccle.head(1)
# Out:
#    Unnamed: 0    exp           cnv         np_t_w          np_p_w  \
# 0           0  MYBL1  LOC100130417  1.15019918524  0.258857718139
#
#       np_t_w_null
# 0  0.225918995171

# %%
kid_cloves_tcga.head(1)
# Out:
#    Unnamed: 0            exp   cnv  pos_n  neg_n     pos_mu     neg_mu  \
# 0           0  TMEM84|283673  TPPP    231    754  16.738888  16.894549
#
#       pos_var      neg_var  cohens_d    np_t_w    np_p_w  np_t_w_null  \
# 0  1284.58178  1822.180101 -0.003776 -0.050209  0.959966    -0.452129
#
#    t_shrnk_glob  gene_var_exp
# 0     -0.000706    1697.83178
