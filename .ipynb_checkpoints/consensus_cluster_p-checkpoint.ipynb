# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
cpiv = pd.read_csv('data/brca_1M_clove_pivot.tab.gz', compression='gzip', sep='\t', index_col=0)

# %%
# columns are copy-loss  genes
# rows are expressed genes
# this particular cluster algorithm divides the rows by the column features
cpiv.head()
# Out:
#        A1BG  A1BG-AS1  A1CF  A2M  A2M-AS1  A2ML1  A2MP1  A3GALT2  A4GALT  \
# exp
# A1BG    NaN       NaN   NaN  NaN      NaN    NaN    NaN      NaN     NaN
# A1CF    NaN       NaN   NaN  NaN      NaN    NaN    NaN      NaN     NaN
# A2BP1   NaN       NaN   NaN  NaN      NaN    NaN    NaN      NaN     NaN
# A2LD1   NaN       NaN   NaN  NaN      NaN    NaN    NaN      NaN     NaN
# A2M     NaN       NaN   NaN  NaN      NaN    NaN    NaN      NaN     NaN
#
#        A4GNT     ...      hsa-mir-664  hsa-mir-720  hsa-mir-886  hsa-mir-887  \
# exp              ...
# A1BG     NaN     ...              NaN          NaN          NaN          NaN
# A1CF     NaN     ...              NaN          NaN          NaN          NaN
# A2BP1    NaN     ...              NaN          NaN          NaN          NaN
# A2LD1    NaN     ...              NaN          NaN          NaN          NaN
# A2M      NaN     ...              NaN          NaN          NaN          NaN
#
#        hsa-mir-924  hsa-mir-941-1  hsa-mir-941-2  hsa-mir-941-3  hsa-mir-95  \
# exp
# A1BG           NaN            NaN            NaN            NaN         NaN
# A1CF           NaN            NaN            NaN            NaN         NaN
# A2BP1          NaN            NaN            NaN            NaN         NaN
# A2LD1          NaN            NaN            NaN            NaN         NaN
# A2M            NaN            NaN            NaN            NaN         NaN
#
#        hsa-mir-96
# exp
# A1BG          NaN
# A1CF          NaN
# A2BP1         NaN
# A2LD1         NaN
# A2M           NaN
#
# [5 rows x 25128 columns]

# %%
cpiv.describe()
# Out:
#             A1BG   A1BG-AS1       A1CF        A2M    A2M-AS1      A2ML1  \
# count  44.000000  42.000000  30.000000  36.000000  44.000000  54.000000
# mean   -0.269507   0.255212   0.565019   0.202489  -0.184375  -0.144487
# std     2.300268   2.320446   1.935069   1.879529   1.741855   1.534355
# min    -5.379237  -5.796175  -2.535435  -6.182683  -4.446697  -3.636088
# 25%    -1.602979  -0.722812  -0.967685  -0.658765  -1.255329  -0.809826
# 50%    -0.287729  -0.133235   0.015559   0.270360  -0.312262  -0.076072
# 75%     1.338824   1.468843   1.887925   1.399918   1.180266   0.741225
# max     5.719190   5.287523   5.267207   2.970434   3.800468   3.347922
#
#            A2MP1    A3GALT2     A4GALT      A4GNT     ...      hsa-mir-664  \
# count  40.000000  33.000000  36.000000  41.000000     ...        49.000000
# mean   -0.009179  -0.630778  -0.177507   0.373130     ...        -0.151901
# std     1.575093   2.281774   1.883608   1.693392     ...         1.537660
# min    -2.903278  -4.356908  -4.190286  -3.227709     ...        -4.204985
# 25%    -0.877866  -2.383993  -1.260280  -0.663249     ...        -1.134262
# 50%    -0.052458  -0.866746  -0.385983   0.010023     ...        -0.238292
# 75%     0.920043   0.801785   0.521232   1.720733     ...         0.671455
# max     5.668175   4.358734   4.390652   4.504176     ...         3.825392
#
#        hsa-mir-720  hsa-mir-886  hsa-mir-887  hsa-mir-924  hsa-mir-941-1  \
# count    36.000000    47.000000    32.000000    35.000000      44.000000
# mean     -0.278667     1.060193     0.426049     0.497253      -0.056561
# std       1.568543     4.821151     2.300657     1.797651       1.092472
# min      -2.820236   -13.517480    -5.983080    -3.588830      -1.842533
# 25%      -1.326063    -1.515015    -0.871939    -0.742714      -0.832375
# 50%      -0.383040     1.335964     0.255159     0.575896      -0.181252
# 75%       0.486697     4.547328     2.208723     1.786221       0.523481
# max       3.303981     9.625796     5.739056     4.065676       2.547909
#
#        hsa-mir-941-2  hsa-mir-941-3  hsa-mir-95  hsa-mir-96
# count      36.000000      41.000000   46.000000   41.000000
# mean        0.751492       0.096620    0.438011   -0.647106
# std         1.843001       1.939476    3.476302    1.672729
# min        -2.812406      -3.330182   -5.838250   -4.943587
# 25%        -0.469104      -1.289467   -1.756807   -2.012666
# 50%         0.079753      -0.117993   -0.148360   -0.421961
# 75%         1.880425       0.894309    3.384343    0.544386
# max         5.353918       5.292846    8.979308    2.224833
#
# [8 rows x 25128 columns]

# %%
n = cpiv.isnull().sum()
type(n)
# Out:
# pandas.core.series.Series

# %%
n.sort_values(axis=0, ascending=False)
# Out:
# CALU             20204
# P4HTM            20203
# FGFR3            20203
# VEGFA            20203
# GMDS             20202
# KCNC4-AS1        20202
# SKAP2            20201
# CTD-2270F17.1    20201
# HMGCL            20201
# ARHGEF11         20201
# TMPRSS7          20201
# RNASEL           20201
# CENPO            20201
# OR2T8            20201
# MGAM             20201
# PLB1             20200
# HS6ST2           20200
# SUSD5            20200
# MS4A14           20200
# API5             20200
# AMELX            20200
# IFNL1            20200
# OR2AE1           20200
# GDPGP1           20200
# RP6-206I17.2     20200
# RAB36            20200
# MIR15A           20200
# MIR3115          20199
# C16orf90         20199
# DNAJB14          20199
#                  ...
# RP5-1070A16.1    20162
# RP11-5P22.3      20161
# TDRD5            20161
# MIR6891          20161
# H3F3C            20161
# MIR3146          20161
# ABHD2            20161
# TM9SF2           20161
# KRTAP4-7         20161
# CBR3             20161
# CHN2             20161
# MAP3K14-AS1      20160
# ZNF530           20160
# CYSLTR1          20160
# TRPM6            20160
# CIB4             20160
# OR8K5            20160
# EPT1             20160
# SRP14            20159
# SNORA80          20159
# SNORD81          20159
# EIF3M            20159
# MIR5091          20158
# PRAMEF15         20158
# PPP3R2           20158
# DYNLT3           20157
# PRR20C           20157
# CHRNA6           20156
# TRAF3IP1         20156
# SHISA7           20156
# dtype: int64

# %%
# there are a lot of missing values!
# try imputing

from sklearn.preprocessing import Imputer, StandardScaler

imputer = Imputer(missing_values = 'NaN', strategy='median', axis=1).fit(cpiv)
cpiv = imputer.transform(cpiv)
scaler = StandardScaler()
cpiv = scaler.fit_transform(cpiv)

# %%
######
